# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
photo = cv2.imread('/content/IMG20240318084058.jpg')
print("ORIGINAL IMAGE")
photo.shape
cv2_imshow(photo)
photo.size
Gray = cv2.cvtColor(photo,cv2.COLOR_BGR2GRAY)
print("GRAY SCALE")
cv2_imshow(Gray)
# Out:
# ORIGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=1004x1336>
# GRAY SCALE
# <PIL.Image.Image image mode=L size=1004x1336>

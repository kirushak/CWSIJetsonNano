# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# Load the image
photo = cv2.imread('/content/test.jpg')

# Display original image
print("ORIGINAL IMAGE")
cv2_imshow(photo)

# Convert to grayscale
gray = cv2.cvtColor(photo, cv2.COLOR_BGR2GRAY)

# Display grayscale image
print("GRAY SCALE")
cv2_imshow(gray)

# Apply a colormap for thermal effect
thermal = cv2.applyColorMap(gray, cv2.COLORMAP_HOT)

# Display thermal image
print("THERMAL IMAGE")
cv2_imshow(thermal)
# Out:
# ORIGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=806x886>
# GRAY SCALE
# <PIL.Image.Image image mode=L size=806x886>
# THERMAL IMAGE
# <PIL.Image.Image image mode=RGB size=806x886>
